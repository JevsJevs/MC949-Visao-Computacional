# %% [markdown]
# # Feature extraction

# %% [markdown]
# ## Notebook setup

# %%
from src.utils import image_utils
from src.utils import notebook_utils

from src.process import feature_extraction
import cv2
import matplotlib.pyplot as plt

# %%
images = image_utils.load_raw_images("FotosICMural")
print("load sucess")
# Out:
# load sucess

# %% [markdown]
# ## SIFT
#
# O mais robusto e usado detector de keypoints

# %%
image = images["1"]
notebook_utils.show_image(image)

# %%
keypoints, descriptors = feature_extraction.SIFT(image)
print(f"Detectado {len(keypoints)} keypoints!")
# Out:
# Detected 157572 keypoints!

# %%
#imagem com keypoints
notebook_utils.show_image_with_keypoints(image, keypoints)

# %%
# como um descriptor se parece

print(descriptors[0].shape)
print(descriptors[0])
# Out:
# (128,)
# [  0.   0.   0.   0.   0.   0.   0.   0.   7.   3.   0.   0.   0.   0.
#    1.   4.  53.  28.   0.   0.   0.   5.  60.  44. 122.  94.   4.  22.
#   52.   6.  25.  43.   0.   0.   0.   0.   3.   4.   0.   0.  85.  21.
#    1.   0.  23.  27.   3.  14. 122.  46.  25.   6.   1.   7. 110. 122.
#   50.  15.  72.  56.  75.  13.  88. 122.   0.   0.   2.   2.  23.  24.
#    2.   0.  46.   7.   3.   2.  55.  73.  34.  88. 122.  66.  88.  65.
#   38.   4.  19.  90.  67.  74. 122.  81.  32.  18.   7.   7.   1.   8.
#   33.  66.  25.   9.   1.   3.  15.  38.  53.  29.  12.  17.  13.  26.
#   27.  36.  37.  35.  52.  26.  29.  42.  61.  50.  19.  16.  16.  53.
#   33.   9.]
