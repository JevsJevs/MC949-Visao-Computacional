# %%
from src.utils import imageutils

# %%
images = imageutils.load_raw_images("FotosICMural")
print("load sucess")
# Out:
# load sucess

# %%
images
# Out:
# {'1': array([[[ 66,  77,  75],
#          [ 52,  63,  61],
#          [ 59,  70,  68],
#          ...,
#          [167, 153, 141],
#          [171, 157, 145],
#          [166, 152, 140]],
#
#         [[ 58,  69,  67],
#          [ 52,  63,  61],
#          [ 65,  76,  74],
#          ...,
#          [171, 157, 145],
#          [172, 158, 146],
#          [170, 156, 144]],
#
#         [[ 46,  54,  54],
#          [ 47,  55,  55],
#          [ 82,  90,  90],
#          ...,
#          [173, 159, 147],
#          [170, 156, 144],
#          [171, 157, 145]],
#
#         ...,
#
#         [[ 92, 144, 150],
#          [ 88, 140, 146],
#          [ 79, 131, 137],
#          ...,
#          [ 72, 123, 133],
#          [ 71, 122, 132],
#          [ 44,  95, 105]],
#
#         [[ 86, 138, 144],
#          [ 84, 136, 142],
#          [ 78, 130, 136],
#          ...,
#          [ 75, 126, 136],
#          [ 75, 124, 134],
#          [ 51,  97, 108]],
#
#         [[ 73, 125, 131],
# ...
